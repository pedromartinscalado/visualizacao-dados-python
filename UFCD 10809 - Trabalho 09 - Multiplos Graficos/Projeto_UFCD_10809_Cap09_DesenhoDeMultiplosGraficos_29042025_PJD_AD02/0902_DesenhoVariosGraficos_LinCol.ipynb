# %% [markdown]
# ################################
# # Cell 01:
# ################################
#
# <h1> Desenho de Múltiplos Gráficos </h1>
#
# <h1 style="background-color:orange;color:white;padding-top:10px;text-align:center;font-weight:bold;font-style:italic;font-size:2cm;padding-bottom:30px;">Desenho de Múltiplos Gráficos</h1>
#
#  Markdown
#  SHIFT + ENTER

# %% [markdown]
# ################################
# # Cell 02:
# ################################
#
# <div style="margin-left:2%;">
# <img style="float:left;margin:2px;height:150px;" src="https://www.analyticssteps.com/backend/media/thumbnail/6350483/7807104_1578230927_time_analysis_tittle-banner%20(1).jpg" width="32%"/>
# <img style="float:left;margin:2px;height:150px;" src="https://www.analyticssteps.com/backend/media/thumbnail/6350483/7807104_1578230927_time_analysis_tittle-banner%20(1).jpg" width="32%"/>
# <img style="float:left;margin:2px;height:150px;" src="https://www.analyticssteps.com/backend/media/thumbnail/6350483/7807104_1578230927_time_analysis_tittle-banner%20(1).jpg" width="32%"/>
#
# </div>

# %% [markdown]
# ################################
# # Cell 03:
# ################################
#
# <h2> Definindo o Número de Linhas e Colunas </h2>
#
# <h2 style="background-color:orange;color:white;padding-top:10px;text-align:center;font-weight:bold;font-style:italic;font-size:1cm;padding-bottom:20px;"> Definindo o Número de Linhas e Colunas  </h2>
#
#  Markdown
#  SHIFT + ENTER

# %% [markdown]
# ################################
# # Cell 04:
# ################################

# %%
# 01. Importar:
#     Bibliotecas: matplotlib, numpy
#     Módulos: pyplot
import matplotlib.pyplot as plt

# Create a figure with 2 rows and 3 columns of subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 6))
# figsize: 10 - largura ,6 - altura
# Dimensões da figura


# Gráficos da primeira linha
####################################
#Plot on the first subplot
# Primeira linha, primeira coluna
axes[0, 0].plot([1, 2, 3], [4, 5, 6])

# Plot on the second subplot
# Primeira linha, segunda coluna
axes[0, 1].scatter([1, 2, 3], [4, 5, 6])
 
# Plot on the third subplot
# Primeira linha , terceira coluna
axes[0, 2].bar([1, 2, 3], [4, 5, 6])

# Gráficos da segunda linha
####################################
# Plot on the fourth subplot
# Segunda linha, primeira coluna
axes[1, 0].hist([1, 2, 2, 3, 3, 3, 4, 4, 4, 4])

# Segunda linha, segunda coluna
# Plot on the fifth subplot
axes[1, 1].pie([1, 2, 3], labels=["A", "B", "C"])

# Plot on the sixth subplot
# Segunda linha, terceira coluna
axes[1, 2].imshow([[1, 2], [3, 4]])

# Show the figure
plt.show()

# %% [markdown]
# ***************************************************************
