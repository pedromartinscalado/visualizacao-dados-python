# %% [markdown]
# ################################
# # Cell 01:
# ################################
#
# <h1> Gráficos Temporais - "Time Series Visualization" </h1>
#
# <h1 style="background-color:orange;color:white;padding-top:10px;text-align:center;font-weight:bold;font-style:italic;font-size:2cm;padding-bottom:30px;">Gráficos Temporais - "Time Series Visualization" </h1>
#
#  Markdown
#  SHIFT + ENTER

# %% [markdown]
# ################################
# # Cell 02:
# ################################
#
# <div style="margin-left:0px;">
# <img style="float:left;margin:0px;height:150px;" src="https://www.analyticssteps.com/backend/media/thumbnail/6350483/7807104_1578230927_time_analysis_tittle-banner%20(1).jpg" width="33%"/>
# <img style="float:left;margin:1px;height:150px;" src="https://www.analyticssteps.com/backend/media/thumbnail/6350483/7807104_1578230927_time_analysis_tittle-banner%20(1).jpg" width="33%"/>
# <img style="float:left;margin:1px;height:150px;" src="https://www.analyticssteps.com/backend/media/thumbnail/6350483/7807104_1578230927_time_analysis_tittle-banner%20(1).jpg" width="33%"/>
# </div>

# %% [markdown]
# ################################
# # Cell 03:
# ################################
#
# <h2>  Exemplo 01 </h2>
#
# <h2 style="background-color:orange;color:white;padding-top:10px;text-align:center;font-weight:bold;font-style:italic;font-size:1cm;padding-bottom:20px;"> Exemplo 01  </h2>
#
#  Markdown
#  SHIFT + ENTER

# %% [markdown]
# ################################
# # Cell 04:
# ################################

# %%
# 01. Importar:
#     Bibliotecas: matplotlib, numpy
#     Módulos: pyplot
import matplotlib.pyplot as plt

# Example data points
x_values = [1, 2, 3, 4, 5]
y_values = [4, 1, 6, 3, 10]

# Plot the data points
plt.plot(x_values, y_values, 'o-', label='Data')

# Add labels and title to the plot
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Title of the plot')

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ################################
# # Cell 05:
# ################################
#
# <h2> Exemplo 02 - Formatos de datas diferente </h2>
#
# <h2 style="background-color:orange;color:white;padding-top:10px;text-align:center;font-weight:bold;font-style:italic;font-size:1cm;padding-bottom:20px;"> Exemplo 02 - Formatos de datas diferente  </h2>
#
#  Markdown
#  SHIFT + ENTER

# %% [markdown]
# ################################
# # Cell 06:
# ################################

# %%
# 01. Importar:
#     Bibliotecas: matplotlib, numpy
#     Módulos: pyplot
from datetime import datetime

# Example date string in the original format
date_string = '2022-03-26'

# Convert the date string to a datetime object
date_object = datetime.strptime(date_string, '%Y-%m-%d')

# Convert the datetime object to a string in a new format
new_date_string = date_object.strftime('%d-%m-%Y')

# Print the new date string
print(new_date_string)
# Out:
# 26-03-2022

# %% [markdown]
# ################################
# # Cell 07:
# ################################
#
# <h2> Exemplo 03 - Gráfico Temporal </h2>
#
# <h2 style="background-color:orange;color:white;padding-top:10px;text-align:center;font-weight:bold;font-style:italic;font-size:1cm;padding-bottom:20px;"> Exemplo 03 - Gráfico Temporal  </h2>
#
# Markdown
# SHIFT + ENTER

# %% [markdown]
# ################################
# # Cell 08:
# ################################

# %%
# 01. Importar:
#     Bibliotecas: matplotlib, numpy
#     Módulos: pyplot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
 
# Create a pandas DataFrame with a column of date strings, including a missing value
df = pd.DataFrame({'DataVenda': ['2022-03-26', '2022-03-27', '2022-03-28', '2022-03-29']})
 
 
# Convert the 'date' column to datetime objects using to_datetime() with errors parameter
#df['date'] = pd.to_datetime(df['date'], errors='coerce')
#df['date'] = df['date'].fillna(pd.to_datetime('2022-01-01'))
#df
 
 
# Example data points
y_values = [400, 100, 600, 300]
 
# Plot the data points
plt.plot(df['DataVenda'], y_values, 'o-', label='Data')
 
# Add labels and title to the plot
plt.xlabel('Data de Venda')
plt.ylabel('Unidades Vendidas')
plt.title('Vendas de Produto')
 
# Add a legend to the plot
plt.legend()
 
# Display the plot
plt.show()

# %% [markdown]
# ********************************************************************
