# %% [markdown]
# ################################
# # Cell 01:
# ################################
#
# <h1> Desenho de Gráficos 3D  </h1>
#
#
# <h1 style="background-color:orange;color:white;padding-top:10px;text-align:center;font-weight:bold;font-style:italic;font-size:2cm;padding-bottom:30px;">   Desenho de Gráficos 3D </h1>
#
#  Markdown
#  SHIFT + ENTER

# %% [markdown]
# ################################
# # Cell 02:
# ################################
#
# <div style="margin-left:2%;">
# <img style="float:left;margin:2px;height:150px;" src="https://www.analyticssteps.com/backend/media/thumbnail/6350483/7807104_1578230927_time_analysis_tittle-banner%20(1).jpg" width="32%"/>
# <img style="float:left;margin:2px;height:150px;" src="https://www.analyticssteps.com/backend/media/thumbnail/6350483/7807104_1578230927_time_analysis_tittle-banner%20(1).jpg" width="32%"/>
# <img style="float:left;margin:2px;height:150px;" src="https://www.analyticssteps.com/backend/media/thumbnail/6350483/7807104_1578230927_time_analysis_tittle-banner%20(1).jpg" width="32%"/>
# </div>

# %% [markdown]
# ################################
# # Cell 03:
# ################################
#
# <h2> Exemplo 1 </h2>
#
# <h2 style="background-color:orange;color:white;padding-top:10px;text-align:center;font-weight:bold;font-style:italic;font-size:1cm;padding-bottom:20px;">   Exemplo 1  </h2>
#
#
#
#  Markdown
#  SHIFT + ENTER

# %% [markdown]
# ################################
# # Cell 04:
# ################################
#
# # Instalação das bibliotecas
# !pip install matplotlib
# !pip install numpy
# !pip install pandas

# %% [markdown]
# ################################
# # Cell 05:
# ################################

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# TR~es séries de 100 números aletórios
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

ax.scatter(x, y, z)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title("3D Scatter Plot")
plt.show()

# %% [markdown]
# ################################
# # Cell 06:
# ################################

# %%
''' Melhorar -> Barras3D
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.array([2010, 2011, 2012])
y = np.array([1, 2, 3])
z = np.array([1, 2, 3])
sizes = 100* np.random.rand(27)
#y = np.array(['Maças', 'Laranjas', 'Cerejas'])
#z = np.array(['Lisboa','Porto','Coimbra'])


ax.scatter(x, y, z, s=sizes, alpha=0.5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title("3D Scatter Plot")
plt.show()
'''


import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


fig = plt.figure()
ax = fig.add_subplot(projection='3d')
x, y = np.random.rand(2, 100) * 4
hist, xedges, yedges = np.histogram2d(x, y, bins=4, range=[[0, 4], [0, 4]])

# Construct arrays for the anchor positions of the 16 bars.
xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25, indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

# Construct arrays with the dimensions for the 16 bars.
dx = dy = 0.5 * np.ones_like(zpos)
dz = hist.ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')

plt.show()

# %% [markdown]
# ******************************************************************
