# %% [markdown]
# ################################
# # Cell 01:
# ################################
#
# <h1> Desenho de Gráficos de Contorno  </h1>
#
# <h1 style="background-color:orange;color:white;padding-top:10px;text-align:center;font-weight:bold;font-style:italic;font-size:2cm;padding-bottom:30px;">  Desenho de Gráficos de Contorno </h1>
#
#  Markdown
#  SHIFT + ENTER

# %% [markdown]
# ################################
# # Cell 02:
# ################################
#
# <div style="margin-left:2%;">
# <img style="float:left;margin:2px;height:150px;" src="https://www.analyticssteps.com/backend/media/thumbnail/6350483/7807104_1578230927_time_analysis_tittle-banner%20(1).jpg" width="32%"/>
# <img style="float:left;margin:2px;height:150px;" src="https://www.analyticssteps.com/backend/media/thumbnail/6350483/7807104_1578230927_time_analysis_tittle-banner%20(1).jpg" width="32%"/>
# <img style="float:left;margin:2px;height:150px;" src="https://www.analyticssteps.com/backend/media/thumbnail/6350483/7807104_1578230927_time_analysis_tittle-banner%20(1).jpg" width="32%"/>
# </div>

# %% [markdown]
# ################################
# # Cell 03:
# ################################
#
# <h2> Exemplo 1 </h2>
#
# <h2 style="background-color:orange;color:white;padding-top:10px;text-align:center;font-weight:bold;font-style:italic;font-size:1cm;padding-bottom:20px;">   Exemplo 1  </h2>
#
#
#
#  Markdown
#  SHIFT + ENTER

# %% [markdown]
# ################################
# # Cell 04:
# ################################
#
# # Instalação das bibliotecas
# !pip install matplotlib
# !pip install numpy
# !pip install pandas

# %% [markdown]
# ################################
# # Cell 05:
# ################################

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

plt.contourf(X, Y, Z, 20, cmap='RdGy') # Filled contours with 20 levels
plt.colorbar() # Add a colorbar
plt.title("Contour Plot Example")
plt.show()

# %% [markdown]
# ################################
# # Cell 06:
# ################################

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.cos(np.sqrt(X**2 + Y**2))

plt.contourf(X, Y, Z, 20, cmap='RdGy') # Filled contours with 20 levels
plt.colorbar() # Add a colorbar
plt.title("Contour Plot Example")
plt.show()

# %% [markdown]
# ################################
# # Cell 07:
# ################################

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.tan(np.sqrt(X**2 + Y**2))

plt.contourf(X, Y, Z, 20, cmap='viridis') # Filled contours with 20 levels
plt.colorbar() # Add a colorbar
plt.title("Contour Plot Example")
plt.show()

# %% [markdown]
# ################################
# # Cell 08:
# ################################

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.cos(np.sqrt(X**2 + Y**2)*5)

plt.contourf(X, Y, Z, 20, cmap='RdGy') # Filled contours with 20 levels
plt.colorbar() # Add a colorbar
plt.title("Contour Plot Example")
plt.show()

# %% [markdown]
# ################################
# # Cell 09:
# ################################

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2)*5)

plt.contourf(X, Y, Z, 20, cmap='Wistia') # Filled contours with 20 levels
plt.colorbar() # Add a colorbar
plt.title("Contour Plot Example")
plt.show()

# %% [markdown]
# ################################
# # Cell 10:
# ################################

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-20, 20, 400)
y = np.linspace(-20, 20, 400)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

plt.contourf(X, Y, Z, 20, cmap='Wistia') # Filled contours with 20 levels
plt.colorbar() # Add a colorbar
plt.title("Contour Plot Example")
plt.show()

# %% [markdown]
# ***************************************************************
